# %% [markdown]
# ### IMPORTS

# %%
# Librerías para llamar a la API de Spotify
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util

# Librerías para la manipulación de datos
import pandas as pd
from collections import Counter
from random import shuffle
from datetime import datetime as dt
from IPython.display import Image
import time
import json

pd.set_option("display.max_rows", 100)
pd.set_option("display.max_colwidth", 1000)

# %% [markdown]
# ### GLOBAL VARIABLES

# %%
# Importo las variables globales de otros archivos
import global_variables as gv
genres = gv.genres
client_ID = gv.client_ID
client_secret = gv.client_secret
sp = gv.sp
host = gv.host
find_URI = gv.find_URI

# La variable artists_genres se nutre cada vez que una canción nueva pasa por mi pipeline
with open('artists_genres.json') as json_file:  
    artists_genres = json.load(json_file)

# %% [markdown]
# ### USERS IDENTIFICATION

# %%
# Recibo los Spotify URI's de los usuarios que van a linkear su música

def receive_users():
    
    print("Enter the Spotify URLs of the profiles you would like to link.\n")
    print("You can easily find your profile URL on the Spotify mobile app by following these 4 steps:\n")
    
    users_URLs = input("\n Paste your Spotify URLs here, separating them by ', ':"
                        ).split(", ")
    
# Creo un diccionario donde guardo los URIs de los usuarios con su display_name
# correspondiente.

    users_URIs = {}
    
# A partir de las URLs, obtengo los URIs de los usuarios:
    
    for user_url in users_URLs:
        display_name = sp.user(user_url[30:].split("?")[0])["display_name"]
        if display_name != None:
            users_URIs[user_url[30:].split("?")[0]] = display_name
        else:
            users_URIs[user_url[30:].split("?")[0]] = user_url[30:]
            
    # print(users_URIs)
        
# Devuelvo esa diccionario
    return users_URIs

# %% [markdown]
# ### OBTAIN USERS' PLAYLISTS

# %%
# Para que los usuarios puedan escoger de entre sus playlists, las obtengo a través de
# sp.user_playlists, y se las muestro para que puedan seleccionarlas sin volver a Spotify.

def get_user_playlists(users_URIs):

# Creo un diccionario donde relaciono cada usuario con los nombres de sus playlists y sus respectivos
# URIs. Me va a servir tanto para mostrar el listado de sus playlists a cada usuario, como para
# obtener las URIs a partir de los nombres de playlists que los usuarios me pasen.

#                  {user1: {pl1_name: pl1_URI, pl2_name: pl2_URI}, ...}

    users_playlists_names_URIs = {}

# Para cada usuario, obtengo sus playlists, y guardo sus datos en el diccionario.

    for user_uri in users_URIs:
        playlists = sp.user_playlists(user_uri)
        users_playlists_names_URIs[user_uri] = {}
        
        for i, playlist in enumerate(playlists["items"]):
            users_playlists_names_URIs[user_uri][playlist["name"]] = playlist['uri'][17:]
        
    #print(users_playlists_names_URIs)


# Creo una variable que va a contener los datos de la petición (playlist por usuario, 
# género a filtrar, y nombre de la nueva lista).
  
#                mygroup = {"users": {user1: [playlists_to_select], 
#                                     user2: [playlists_to_select]},
#                           "genres": [genres_to_select],
#                           "new_playlist_name": name}

    mygroup = {"users": {}}
    for user_uri in users_URIs:
        mygroup["users"][user_uri] = {} 
        

# Doy la opción a los usuarios de escoger si quieren seleccionar todas sus playlists
# o no, para que, en caso de querer seleccionar todas, no tengan que ir uno a uno 
# escribiendo "all".

    select_playlists = input("""
     If you would like to select which playlists from your profiles to submit, write 'select'. 
                             
     If you rather want to submit them all, write 'all'
                             
     """)
    
# Si han escogido "all", entonces en mygroup se guarda ["all"] en playlists_to_select
# para todos los usuarios.
        
    if select_playlists == "all":
        for user_uri in users_URIs:
            mygroup["users"][user_uri] = []
            for playlist in users_playlists_names_URIs[user_uri]:
                mygroup["users"][user_uri].append(playlist)
        
# Si han escogido "select", entonces en playlists_to_select se guarda la lista de 
# playlists que introduzcan en el siguiente input, donde muestro su display_name
# y el nombre de todas sus playlists.

    else:    
        for user_uri in users_URIs:
            selected_playlists = input(
                """
                ·················································
                ·················································
                ·················································

                {} , enter the Spotify playlists you would like to submit. 

                These are all your public playlists: 

                {} 
                
                If you want to submit all, just write "all"
                
                This time, separate the playlists by '//'.

                """
                .format(users_URIs[user_uri], 
                        list(users_playlists_names_URIs[user_uri].keys()))).split("//")
                
            if selected_playlists == ["all"]:
                mygroup["users"][user_uri] = []
                for playlist in users_playlists_names_URIs[user_uri]:
                    mygroup["users"][user_uri].append(playlist)
            else: 
                mygroup["users"][user_uri] = selected_playlists

# Una vez han seleccionado las playlists que quieran subir, les ofrezco el filtro 
# por género. Recibo su respuesta a través de un input donde le muestro los géneros
# generales de entre los que pueden seleccionar (guardados en mi variable global genres),
# y la guardo en mygroup["genres"].

    mygroup["genres"] = input(
            """
            ·················································
            ·················································
            ·················································
            
            Now select the genres of the songs for your new playlist.
                        
            You can select out of the following:
    
            {} 
            
            
            If you don't want to filter by genre, just write "any"
            
            Again, separate by '//'
                        
            """
            .format(list(genres.keys()))).split("//")

# Finalmente, escriben el nombre de la nueva playlist, y lo guardo en 
# mygroup["new_playlist_name"]

    mygroup["new_playlist_name"] = input(
            """
            ·················································
            ·················································
            ·················································
            
            And finally, write the name for your new combined playlist :D            
            
            """
            )
    
    #print("PL_NAMES_URIS:", users_playlists_names_URIs)
    #print("MYGROUP:", mygroup)
    

# Devuelvo el diccionario donde relaciono los nombres de las playlists de un usuario con 
# sus URIs, mygroup, y el diccionario que relaciona URIs de usuarios y sus display_names.

    return users_URIs, users_playlists_names_URIs, mygroup

# %% [markdown]
# ### SAVE PLAYLISTS

# %%
# Ahora que ya tengo las playlists que cada usuario quiere subir, guardo sus URIs y la 
# información de sus temas en la variable global playlists_tracks.
# Si ya tengo una playlist guardada de una petición anterior, entonces no tendré que
# llamar a la API para obtener la información de sus temas.

def save_playlists_tracks(users_URIs, users_playlists_names_URIs, mygroup):
    
# Guardo la hora para calcular cuánto tarda desde aquí hasta el final.
    
    start_time = time.time()
    

# Creo una variable donde voy a guardar la información relevante de los temas de cada playlist

# user_playlists_tracks = 

# {user1_uri: [{playlist1_uri: [{"track_uri": track1_uri, 
#                               "track_name": track1_name, 
#                               "artist": [track1_artist_name, track1_artist_uri], 
#                               "date_added": track1_date},
#                              {"track_uri": track2_uri, 
#                               "track_name": track2_name, 
#                               "artist": [track1_artist_name, track1_artist_uri], 
#                               "date_added": track2_date}],
#              playlist2_uri: [...]}],
#  user2_uri: ...}


    user_playlists_tracks = {}
    
# Itero sobre cada usuario de la petición, guardando sus playlists con sus respectivos
# temas en playlists_tracks:
        
    for user_uri in users_URIs:
        
        print("Obtaining tracks info from {}".format(users_URIs[user_uri]))
        
        user_playlists_tracks[user_uri] = []
        
        count = 0
            
        for playlist in mygroup["users"][user_uri]:
            playlist_uri = users_playlists_names_URIs[user_uri].get(playlist)
            user_playlists_tracks[user_uri].append({playlist_uri: []})
            tracks_info = sp.user_playlist_tracks(user_uri, playlist_id = playlist_uri)
            for track in tracks_info["items"]:
                if track["track"] != None:
                    if track["track"]["id"] != None:
                        #print(user_playlists_tracks[user_uri])
                        date_added = dt.strptime(track["added_at"][:10], '%Y-%m-%d').date()
                        user_playlists_tracks[user_uri][count][playlist_uri].append({"track_uri": track["track"]["id"], 
                                                                                     "track_name": track["track"]["name"], 
                                                                                     "artist": [track["track"]["artists"][0]["name"],
                                                                                                track["track"]["artists"][0]["id"]],
                                                                                     "date_added": date_added})
            
            count += 1                      
                                                              
    # print("PLAYLISTS TRACKS:", user_playlists_tracks)         
    
    return users_URIs, mygroup, start_time, user_playlists_tracks

# %% [markdown]
# ### OBTAIN FINAL TRACKS

# %%
# Ya tengo toda la info de los temas de las playlists a combinar. 
# Ahora tengo que obtener los temas finales, filtrando por género/fecha de subida en 
# caso de que se haya especificado así.

def get_final_tracks(users_URIs, mygroup, start_time, user_playlists_tracks):
    
# Creo un diccionario donde voy a guardar la información de los temas con los que me 
# voy a quedar.      final_tracks = {track_URI: {track_name: artist}}
    
    final_tracks = {}
    
# Creo listas vacías para introducir después sus valores en final_tracks.
# Si introdujese directamente los valores en final_tracks, al ser un diccionario,
# no guardaría repetidos, sino que reescribiría los valores de las key repetidas.

# Sin embargo, yo voy a necesitar la lista final_track_IDs con repetidos, para poder 
# así calcular más adelante la frecuencia de cada tema.
    
    final_track_URIs = []
    final_track_names = []
    final_track_artists = []
    
# Itero sobre cada usuario

    for user_uri in user_playlists_tracks:
        
        print("Obtaining final tracks from {}".format(users_URIs[user_uri]))
        
        # Para cada usuario creo una lista de sus canciones con valores únicos. 
        # Esto lo hago para evitar que un usuario con la misma canción en distintas
        # playlists incluya varias veces la canción en la lista final, dándole mayor 
        # popularidad porque se repite entre sus listas, pero sin que realmente sea 
        # popular entre los distintos perfiles.
        
        user_track_URIs = []
        user_track_names = []
        user_track_artists = []
        

# Itero sobre cada playlist de cada usuario

        for pl in user_playlists_tracks[user_uri]:
        
        # Itero sobre cada tema de cada playlist
        
            for playlist_uri in pl:
             #   print(pl)
                
                for track in pl[playlist_uri]:
                
                    if track["track_name"] not in user_track_names:  # Aquí evito repetición.
                            
                        # Si los usuarios no han filtrado por género, cojo todos.
                            
                        if mygroup["genres"] == ["any"]:
                            user_track_URIs.append(track["track_uri"])
                            user_track_names.append(track["track_name"])
                            user_track_artists.append(track["artist"][0])
                                
                        # Si los usuarios sí que han filtrado por género, cojo el
                        # URI del artista de la canción, y utilizo sp.artist para obtener
                        # el género del artista.

                        else:
                            artist_uri = track["artist"][1]
                                
                    # Tengo una variable global (artists_genres), donde voy guardando 
                    # artistas y sus géneros, para evitar llamadas a la API y reducir así
                    # el tiempo del proceso entero. 
                    # Si no tengo guardado a ese artista en la variable, entonces llamo a la
                    # API, y lo guardo en la variable con su género correspondiente.
                                
                            if artist_uri not in artists_genres:
                                artist_info = sp.artist(artist_uri)
                                artists_genres[artist_uri] = artist_info["genres"]
                                
                    # Hay artistas de reggaeton que incluyen "pop" entre sus géneros. 
                    # Evito que sus canciones puedan ser seleccionados como pop.

                            if "reggaeton" in artists_genres[artist_uri]:
                                artists_genres[artist_uri] = ["reggaeton"]
                                                    
                                    
                    # Si alguno de los géneros incluidos en el general_genre que me han pasado 
                    # los usuarios aparece en el listado de géneros del artista (guardado ya en
                    # artists_genres), entonces meto la canción en la lista de canciones finales
                    # del usuario.

                            genre_in_artist = 0

                            for general_genre in mygroup["genres"]:
                                 for genre in genres[general_genre]:
                                    if genre in artists_genres[artist_uri]:
                                        genre_in_artist += 1
                            if genre_in_artist > 0:
                                user_track_URIs.append(track["track_uri"])
                                user_track_names.append(track["track_name"])
                                user_track_artists.append(track["artist"][0])

# Introduzco las listas de canciones finales del usuario en las listas globales de todos
# los usuarios. (Recuerda que lo he hecho para evitar repetición dentro de un mismo usuario).
                            
        for i in range(len(user_track_names)):
            final_track_URIs.append(user_track_URIs[i])
            final_track_names.append(user_track_names[i]) 
            final_track_artists.append(user_track_artists[i])    
            
# Y guardo las listas globales en el diccionario global (donde no se podrá medir la frecuencia).
    
    for i in range(len(final_track_URIs)):
        final_tracks[final_track_URIs[i]] = [final_track_names[i], final_track_artists[i]]
        
    
    # Hago este shuffle antes de ordenarlos por popularidad para evitar que las canciones con 
    # el mismo número de repeticiones se ordenen según el orden de introducción de los 
    # nombres de usuarios. Lo quiero aleatorio:
    
    shuffle(final_track_URIs)
    
    # Ordeno los temas por popularidad en una nueva variable
    
    final_track_URIs_pop = [item for items, c in Counter(final_track_URIs).most_common() for item in [items] * c]
    
    # Creo una lista para obtener valores únicos de los temas finales, ordenados por
    # popularidad
    
    final_track_URIs_unique_all = []
    
    for track_URI in final_track_URIs_pop:
        if track_URI not in final_track_URIs_unique_all:
            final_track_URIs_unique_all.append(track_URI)
            
    # Creo otra lista con solo los temas que aparecen repetidos, para utilizarla
    # después al mostrar el dataframe:
    
    final_track_URIs_unique_repeated = []
    
    for track in final_track_URIs_unique_all:
        if final_track_URIs_pop.count(track) > 1:
            final_track_URIs_unique_repeated.append(track)
            
    # La lista final en Spotify va a tener como máximo 50 canciones:
            
    if len(final_track_URIs_unique_all) > 50: 
        final_track_URIs_unique = final_track_URIs_unique_all[:50]
    else:
        final_track_URIs_unique = final_track_URIs_unique_all
            
    print("READY!")
    
# Devuelvo el diccionario que relaciona URIs con nombres de temas y artistas, la lista de temas
# finales con valores únicos, la lista de temas finales con repetidos, mygroup y start_time

    return users_URIs, mygroup, start_time, final_tracks, final_track_URIs_pop, final_track_URIs_unique, user_playlists_tracks, final_track_URIs_unique_repeated

# %% [markdown]
# ### CREATE DATAFRAME FOR DJ

# %%
# Creo un dataframe que me muestre las canciones finales ordenadas por popularidad:
# su URI, nombre, artista y frecuencia.

def create_dataframe(users_URIs, mygroup, start_time, final_tracks, final_track_URIs_pop, 
                     final_track_URIs_unique, user_playlists_tracks, final_track_URIs_unique_repeated):
    
# Creo listas que voy a utilizar como columnas en el dataframe

    tracks = []
    artists = []
    frequency = []

# Obtengo los datos de la lista ordenada de URIs finales, buscando sus datos correspondientes
# en el diccionario final_tracks, y contando la frecuencia de los temas en final_track_URIs_pop.

    for URI in final_track_URIs_unique_repeated:
            tracks.append(final_tracks.get(URI)[0])
            artists.append(final_tracks.get(URI)[1])
            frequency.append(final_track_URIs_pop.count(URI))
            
# Busco en qué listas aparecen las canciones:
    
    users = []
    
    count = 0

    for track_uri in final_track_URIs_unique_repeated:
        users.append([])
        for user_uri in user_playlists_tracks:
            for i in user_playlists_tracks[user_uri]:
                for playlist_uri in i:
                    for e in i[playlist_uri]:
                        if track_uri in e["track_uri"]:
                            users[count].append(users_URIs.get(user_uri))
                            
        count += 1
        
            
# Creo el dataframe

    final_tracks_df = pd.DataFrame(data = [final_track_URIs_unique_repeated, tracks, artists, frequency, users],
                                   columns = range(len(final_track_URIs_unique_repeated)), 
                                   index = ["ID", "Track", "Artist", "Frequency", "Users"]).T
    
    display(final_tracks_df)
    
# Devuelvo la lista de URIs de temas finales únicos, mygroup y start_time

    return mygroup, start_time, final_track_URIs_unique

# %% [markdown]
# ### CREATE PLAYLIST ON SPOTIFY

# %%
# Teniendo ya el listado ordenado de URIs de los temas finales, creo la playlist en Spotify

def create_playlist(mygroup, start_time, final_track_URIs_unique):
    
# Para crear una playlist necesito un token especial.

    token = util.prompt_for_user_token(host,
                               "playlist-modify-public",
                               client_id = "{}".format(client_ID),
                               client_secret = "{}".format(client_secret),
                               redirect_uri = "https://example.com/callback/")
    

# Con la autorización del nuevo token, creo la nueva playlist en el perfil del perfil de 
# la aplicación.

    sp = spotipy.Spotify(auth = token)
    final_playlist = sp.user_playlist_create(host, mygroup["new_playlist_name"])
    
# Añado los temas a la nueva playlist:

    sp.user_playlist_add_tracks(host, final_playlist["uri"][17:], final_track_URIs_unique)
    
# Obtengo su URL, y la comparto con los usuarios:

    final_playlist_url = final_playlist["external_urls"]["spotify"]
    
    print("""
          ·················································
          ·················································
          ·················································
          
          Here's your new combined playlist: 
          
          {}
          
          ENJOY!
          """.format(final_playlist["external_urls"]["spotify"])
          )
    
    elapsed_time = time.time() - start_time
    print("Elapsed time:", elapsed_time)

# %% [markdown]
# ### PIPELINE

# %%
if __name__ == '__main__':
    
    users_URIs = receive_users()
    
    users_URIs, users_playlists_names_URIs, mygroup = get_user_playlists(users_URIs)
    
    users_URIs, mygroup, start_time, user_playlists_tracks = save_playlists_tracks(users_URIs, users_playlists_names_URIs, mygroup)
    
    users_URIs, mygroup, start_time, final_tracks, final_track_URIs_pop, final_track_URIs_unique, user_playlists_tracks, final_track_URIs_unique_repeated = get_final_tracks(users_URIs, mygroup, start_time, user_playlists_tracks)
    
    mygroup, start_time, final_track_URIs_unique = create_dataframe(users_URIs, mygroup, start_time, final_tracks, final_track_URIs_pop, final_track_URIs_unique, user_playlists_tracks, final_track_URIs_unique_repeated)
    
    create_playlist(mygroup, start_time, final_track_URIs_unique)
# Out:
# Enter the Spotify URLs of the profiles you would like to link.
#
# You can easily find your profile URL on the Spotify mobile app by following these 4 steps:
#
#
#  Paste your Spotify URLs here, separating them by ', ':https://open.spotify.com/user/12128396108, https://open.spotify.com/user/1185239584?si=QIywiHyvTgCyn04_RrH9Jw, https://open.spotify.com/user/marcpomar?si=_xiGXZG3TIKuLpjvFJXsYw, https://open.spotify.com/user/gabaxi, https://open.spotify.com/user/sithjacob?si=lso8-7caRQuu6wqDSJg9Dg, https://open.spotify.com/user/1143476756?si=ewKVuIuWT26FUjSbAvpX-A, https://open.spotify.com/user/delgadito92?si=HZ9puV_qRY-aziF-jwyKzQ, https://open.spotify.com/user/1116864324?si=oJSFGvfRQlGz7-yMkdNcAg, https://open.spotify.com/user/pipen319?si=uxTraEFQT4ibv9T6mx-D3w, https://open.spotify.com/user/kaarlikds?si=N8RD41MZRF2aeHXkn5qdtw, https://open.spotify.com/user/c5lj42ggby4c8p0aodcv15usk?si=GoEkZ0flTiy8g_9hqVKS6w, https://open.spotify.com/user/melecasas?si=Q2ZD0FmnRISwSvvfC_qPUg, https://open.spotify.com/user/merloc?si=r1ULZar4Sw6wdW3GEGey-g
#
#      If you would like to select which playlists from your profiles to submit, write 'select'.
#
#      If you rather want to submit them all, write 'all'
#
#      all
#
#             ·················································
#             ·················································
#             ·················································
#
#             Now select the genres of the songs for your new playlist.
#
#             You can select out of the following:
#
#             ['Chill House', 'Indie', 'Pop', 'Rock', 'Latin', 'Electronic/Dance', 'Trap', 'Techno', 'Hip hop']
#
#
#             If you don't want to filter by genre, just write "any"
#
#             Again, separate by '//'
#
#             Pop//Rock//Latin//Electronic/Dance
#
#             ·················································
#             ·················································
#             ·················································
#
#             And finally, write the name for your new combined playlist :D
#
#             DATAMAD0419 - Party
# Obtaining tracks info from Martin Molestina Luzuriaga
# Obtaining tracks info from Sonia Fresa
# Obtaining tracks info from Marc Pomar Torres
# Obtaining tracks info from Cecil Fernandez
# Obtaining tracks info from sithjacob
# Obtaining tracks info from Potacho Garcia Moreno
# Obtaining tracks info from delgadito92
# Obtaining tracks info from Juanjo P Fdez
# Obtaining tracks info from Ivan Peña
# Obtaining tracks info from kaarlikds
# Obtaining tracks info from Garcia.cobo.alberto
# Obtaining tracks info from Domènec Melé Casas
# Obtaining tracks info from merloc
# Obtaining final tracks from Martin Molestina Luzuriaga
# Obtaining final tracks from Sonia Fresa
# Obtaining final tracks from Marc Pomar Torres
# Obtaining final tracks from Cecil Fernandez
# Obtaining final tracks from sithjacob
# Obtaining final tracks from Potacho Garcia Moreno
# Obtaining final tracks from delgadito92
# Obtaining final tracks from Juanjo P Fdez
# Obtaining final tracks from Ivan Peña
# Obtaining final tracks from kaarlikds
# Obtaining final tracks from Garcia.cobo.alberto
# Obtaining final tracks from Domènec Melé Casas
# Obtaining final tracks from merloc
# READY!
#                          ID                                      Track  \
# 0    3AJwUDP919kvQ9QcozQPxg                                     Yellow
# 1    1ozbWlTQASs311dSO5R6vp                          Lucha De Gigantes
# 2    3yP0cohcr97BUNJcgvmSVg                              The Passenger
# 3    75JFxkI2RXiU7L9VXzMkle                              The Scientist
# 4    3AA8xNhDC0MpqwkGX3EP5V                      If I Ever Feel Better
# 5    3ctoHckjyd13eBi2IDw2Ip                          Seven Nation Army
# 6    4UtREbGYnd1nZLckEb5y8J                                   Carolina
# 7    7N3PAbqfTjSEU1edb2tY8j                       Jump - 2015 Remaster
# 8    4dyx5SzxPPaD8xQIid5Wjj                                Young Folks
# 9    3tm3GG9BBOYhUzKWlS6A74                              Vivir Mi Vida
# 10   48psxWnIVYCPUZJKiuDiEf                 The Man Who Sold The World
# 11   5zF2zGPkL6Ipsn9AfAK6RP                                  This Love
# 12   33fdvicpRVPWCPz19Obajn                              Back To Black
# 13   37cb7mzkQKksGm0noGDXeh                           Trying Your Luck
# 14   2LlvrdnLa3XbB1b4jYuCnl                                  R U Mine?
# 15   3XXLQJEHglT1zeSxSFfD2G                             Something Good
# 16   1qrV076T6ZPUPQ2iMgI51s                                      Crime
# 17   1jJci4qxiYcOHhQR247rEU                                       Kids
# 18   2JO3HwMRPeya8bXbtbyPcf                    Love Will Tear Us Apart
# 19   4e8KvQ6kLYr4ZnmZyNLwJO                                       Taro
# 20   34gCuhDGsG4bRPIf9bb02f                          Thinking out Loud
# 21   7E8ghSMY1pCO8f7erlKP8U                                    Believe
# 22   6YZdkObH88npeKrrkb8Ggf                           DUELE EL CORAZON
# 23   1FHNctV68GUNLgXclG2DtR                   Dancing in the Moonlight
# 24   1ytTeSRAU6IRo2itVDwtPv                                      Creep
# 25   29tVNOmg85qDLh2wVnJxpv                 Alli donde soliamos gritar
# 26   0xIVvRmjztR1AwuHrkhH41                            Addicted To You
# 27   336ZYcU6poBWi3s8yzRcAD                            I Follow Rivers
# 28   2hmibAtdObO8F4tnhLENuQ                                   Reptilia
# 29   703BT1NQsfIwPFv8MXQ47m                                     Dreams
# 30   1WYEDcS7WGjv0rG7rmMX3o                      Bitter Sweet Symphony
# 31   7iqTu4OPL3KYs4FMdtLZsy                                  Mardy Bum
# 32   7IHOIqZUUInxjVkko181PB                               Stay With Me
# 33   6mcxQ1Y3uQRU0IHsvdNLH1                          Where Is My Mind?
# 34   7zrYKlgYQv1ELz7LGyjTd1                                  Bang Bang
# 35   7LRMbd3LEoV5wZJvXT1Lwb                                     T.N.T.
# 36   0dCr3qIupWh36ilLjRHi4P              Virtual Insanity - Remastered
# 37   0MnI39P9Dze0PSUjetb8Va                                Black Betty
# 38   5ZCamgcqvkckdf2FdfYuth                                 La Llamada
# 39   2DFRFqWNahKtFD112H2iEZ                           Do You Realize??
# 40   1fidCEsYlaVE3pHwKCvpFZ                                 Am I Wrong
# 41   5xC8uOesnn0udeXAYlAnoY                                    Alright
# 42   39shmbIHICJ2Wxnk1fPSdz  Should I Stay or Should I Go - Remastered
# 43   0FE9t6xYkqWXU2ahLh6D8X                               Shape of You
# 44   4vkSJSyPddHwL7v3l1cuRf           La chispa adecuada (Bendecida 3)
# 45   4qqArAiTPueDxIp7cf87h7                                 Final Song
# 46   1VbhR6D6zUoSTBzvnRonXO                       I'm Not The Only One
# 47   7MmG8p0F9N3C4AXdK6o6Eb                                    Outside
# 48   0HLWvLKQWpFdPhgk6ym58n                                   Who Says
# 49   5dKBaysNJtfpyNTRa5lqDb                                     A-Punk
# ..                      ...                                        ...
# 76   1qRA5BS78u3gME0loMl9AA                        For What It's Worth
# 77   4iZPNYqzI2L0uwuUKun7Aa                             Stole the Show
# 78   1Dl44SWywsIDdz1GgIp9gG                                   Infinity
# 79   4z1XVBfsY1nYL2yedXlKOv                                 Diecinueve
# 80   0QYIp7P4r35lTcrGyznTWO                                  Afterlife
# 81   4c9WmjVlQMr0s1IjbYO52Z                                  My Number
# 82   0wz1LjDb9ZNEYwOmDJ3Q4b                Surfin' U.S.A. - Remastered
# 83   5xoUgPXbMNUmoHU0Enwtwq                   She Moves In Her Own Way
# 84   4toSP60xmDNCFuXly8ywNZ                               Karma Police
# 85   0XPayKZFFZA2PwSRNi1pVU                        Terriblemente Cruel
# 86   4SBqydJCEhcroni09XgT2c           ID - Ultra Music Festival Anthem
# 87   0PEXp5yk0sx9dJ8JzwvjJb                                 Multi-Love
# 88   1RnDdNwGdqTMSTiZmSLYdU                            Maldita Dulzura
# 89   7n3REqDfZBpkd0bEpGu2H3                                  Mr. Jones
# 90   3YBZIN3rekqsKxbJc9FZko                              Paradise City
# 91   08mG3Y1vljYA6bvDt4Wqkj                              Back In Black
# 92   5FVd6KXrgO9B3JPmC8OPst                           Do I Wanna Know?
# 93   0bXpmJyHHYPk6QBFj25bYF                                      Intro
# 94   7wqSzGeodspE3V6RBD5W8L         See You Again (feat. Charlie Puth)
# 95   7vfWgVGiLgnGbInU5lvSQg        I Took A Pill In Ibiza - Seeb Remix
# 96   1QFh8OH1e78dGd3VyJZCAC                             Boys Don't Cry
# 97   4o0NjemqhmsYLIMwlcosvW                                The Funeral
# 98   7e89621JPkKaeDSTQ3avtg                         Sweet Home Alabama
# 99   29SyMC0plk6qw8NMF7lfRL               You Really Got Me - Mono Mix
# 100  225xvV8r1yKMHErSWivnow               I Don't Want to Miss a Thing
# 101  2PaETSKl3w3IdtLIbDnQXJ                        El aire de la calle
# 102  6ooluO7DiEhI1zmK94nRCM                                Take Me Out
# 103  1zHlj4dQ8ZAtrayhuDDmkY                                     Timber
# 104  7KsZHCfOitA5V9oQYVdltG                             Everything Now
# 105  7BKLCZ1jbUBVqRi2FVlTVw                                     Closer
# 106  71O1jD7bF3cdMPvPi186V6                                I Will Wait
# 107  63OFKbMaZSDZ4wtesuuq6f                            Born To Be Wild
# 108  2LawezPeJhN4AWuSB0GtAU                Have You Ever Seen The Rain
# 109  6yl8Es1tCYD9WdSkeVLFw4                You Shook Me All Night Long
# 110  541hgOF71B92Jpg4IU6kyx                                    Turnedo
# 111  7r3oumwvHjsnh5IPtGrfNB                     Everything Goes My Way
# 112  71jGGLe5VtEHjIk5dU2W3S                                   Red Eyes
# 113  66hayvUbTotekKU3H4ta1f       Where Are Ü Now (with Justin Bieber)
# 114  7kzKAuUzOITUauHAhoMoxA                                  Last Nite
# 115  0aePOPP6t864hWQGL8izY5                               Breaking Bad
# 116  3iaj0MtII6VPVhwQa4eeX3                                   Qué Bien
# 117  2sNvitW3TxiTeC9xT9f2ZZ            Firestone (feat. Conrad Sewell)
# 118  386RUes7n1uM1yfzgeUuwp                              The Lazy Song
# 119  6JyuJFedEvPmdWQW0PkbGJ        Purple Lamborghini (with Rick Ross)
# 120  4BP3uh0hFLFRb5cjsgLqDh                              Fortunate Son
# 121  2kP1ujXHn0mNqFbiT3zob8                           What Kind Of Man
# 122  5yc59J3MR3tVDPTOgwgRI5                            Soul Meets Body
# 123  5ZrrXIYTvjXPKVQMjqaumR                                 Loud Pipes
# 124  15vzANxN8G9wWfwAJLLMCg                                      Paris
# 125  0d28khcov6AiegSCpG5TuT                              Feel Good Inc
#
#                            Artist Frequency  \
# 0                        Coldplay         3
# 1                 Love of Lesbian         3
# 2                        Iggy Pop         3
# 3                        Coldplay         3
# 4                         Phoenix         3
# 5               The White Stripes         3
# 6                          M-Clan         3
# 7                       Van Halen         3
# 8            Peter Bjorn and John         3
# 9                    Marc Anthony         2
# 10                        Nirvana         2
# 11                       Maroon 5         2
# 12                  Amy Winehouse         2
# 13                    The Strokes         2
# 14                 Arctic Monkeys         2
# 15                          alt-J         2
# 16                    Real Estate         2
# 17                           MGMT         2
# 18                   Joy Division         2
# 19                          alt-J         2
# 20                     Ed Sheeran         2
# 21                 Mumford & Sons         2
# 22               Enrique Iglesias         2
# 23                      Toploader         2
# 24                      Radiohead         2
# 25                Love of Lesbian         2
# 26                         Avicii         2
# 27                       Lykke Li         2
# 28                    The Strokes         2
# 29                  Fleetwood Mac         2
# 30                      The Verve         2
# 31                 Arctic Monkeys         2
# 32                      Sam Smith         2
# 33                         Pixies         2
# 34                       Jessie J         2
# 35                          AC/DC         2
# 36                     Jamiroquai         2
# 37                        Ram Jam         2
# 38                          Leiva         2
# 39               The Flaming Lips         2
# 40                    Nico & Vinz         2
# 41                     Supergrass         2
# 42                      The Clash         2
# 43                     Ed Sheeran         2
# 44            Heroes Del Silencio         2
# 45                             MØ         2
# 46                      Sam Smith         2
# 47                  Calvin Harris         2
# 48                     John Mayer         2
# 49                Vampire Weekend         2
# ..                            ...       ...
# 76            Buffalo Springfield         2
# 77                           Kygo         2
# 78                         The xx         2
# 79                           Maga         2
# 80                    Arcade Fire         2
# 81                          Foals         2
# 82                 The Beach Boys         2
# 83                      The Kooks         2
# 84                      Radiohead         2
# 85                          Leiva         2
# 86                           Kygo         2
# 87       Unknown Mortal Orchestra         2
# 88                  Vetusta Morla         2
# 89                 Counting Crows         2
# 90                  Guns N' Roses         2
# 91                          AC/DC         2
# 92                 Arctic Monkeys         2
# 93                         The xx         2
# 94                    Wiz Khalifa         2
# 95                    Mike Posner         2
# 96                       The Cure         2
# 97                 Band of Horses         2
# 98                 Lynyrd Skynyrd         2
# 99                      The Kinks         2
# 100                     Aerosmith         2
# 101              Los Delinquentes         2
# 102               Franz Ferdinand         2
# 103                       Pitbull         2
# 104                   Arcade Fire         2
# 105              The Chainsmokers         2
# 106                Mumford & Sons         2
# 107                   Steppenwolf         2
# 108  Creedence Clearwater Revival         2
# 109                         AC/DC         2
# 110                 Ivan Ferreiro         2
# 111                     Metronomy         2
# 112              The War On Drugs         2
# 113                        Jack Ü         2
# 114                   The Strokes         2
# 115                         Leiva         2
# 116                          IZAL         2
# 117                          Kygo         2
# 118                    Bruno Mars         2
# 119                      Skrillex         2
# 120  Creedence Clearwater Revival         2
# 121        Florence + The Machine         2
# 122           Death Cab for Cutie         2
# 123                       Ratatat         2
# 124              The Chainsmokers         2
# 125                      Gorillaz         2
#
#                                                                                        Users
# 0                                         [Cecil Fernandez, delgadito92, Domènec Melé Casas]
# 1                                               [Sonia Fresa, sithjacob, Domènec Melé Casas]
# 2                               [Martin Molestina Luzuriaga, Cecil Fernandez, Juanjo P Fdez]
# 3                               [Cecil Fernandez, delgadito92, Juanjo P Fdez, Juanjo P Fdez]
# 4                            [Martin Molestina Luzuriaga, Juanjo P Fdez, Domènec Melé Casas]
# 5                                   [Martin Molestina Luzuriaga, Cecil Fernandez, Ivan Peña]
# 6                                           [delgadito92, Juanjo P Fdez, Domènec Melé Casas]
# 7                                 [Cecil Fernandez, Garcia.cobo.alberto, Domènec Melé Casas]
# 8    [Martin Molestina Luzuriaga, Martin Molestina Luzuriaga, Ivan Peña, Domènec Melé Casas]
# 9                                                                 [Juanjo P Fdez, Ivan Peña]
# 10                                             [Martin Molestina Luzuriaga, Cecil Fernandez]
# 11                                                    [Potacho Garcia Moreno, Juanjo P Fdez]
# 12                                                    [Potacho Garcia Moreno, Juanjo P Fdez]
# 13                                                            [Sonia Fresa, Cecil Fernandez]
# 14                                                         [delgadito92, Domènec Melé Casas]
# 15                                             [Martin Molestina Luzuriaga, Cecil Fernandez]
# 16                                                                 [Cecil Fernandez, merloc]
# 17                                               [delgadito92, Juanjo P Fdez, Juanjo P Fdez]
# 18                                          [Martin Molestina Luzuriaga, Domènec Melé Casas]
# 19                                                      [Martin Molestina Luzuriaga, merloc]
# 20                [Martin Molestina Luzuriaga, Potacho Garcia Moreno, Potacho Garcia Moreno]
# 21                                                      [Sonia Fresa, Potacho Garcia Moreno]
# 22                                                                  [Sonia Fresa, Ivan Peña]
# 23                                                       [Juanjo P Fdez, Domènec Melé Casas]
# 24                                                              [Sonia Fresa, Juanjo P Fdez]
# 25                                                                  [Sonia Fresa, sithjacob]
# 26                                               [Sonia Fresa, Juanjo P Fdez, Juanjo P Fdez]
# 27                                                                 [Cecil Fernandez, merloc]
# 28                                                 [Martin Molestina Luzuriaga, Sonia Fresa]
# 29                                             [Martin Molestina Luzuriaga, Cecil Fernandez]
# 30                                                    [Potacho Garcia Moreno, Juanjo P Fdez]
# 31                                                     [Cecil Fernandez, Domènec Melé Casas]
# 32                                       [Martin Molestina Luzuriaga, Potacho Garcia Moreno]
# 33                                             [Martin Molestina Luzuriaga, Cecil Fernandez]
# 34                                                      [Sonia Fresa, Potacho Garcia Moreno]
# 35                                                 [Garcia.cobo.alberto, Domènec Melé Casas]
# 36                                     [Potacho Garcia Moreno, Juanjo P Fdez, Juanjo P Fdez]
# 37                                          [Martin Molestina Luzuriaga, Domènec Melé Casas]
# 38                                                         [delgadito92, Domènec Melé Casas]
# 39                                             [Martin Molestina Luzuriaga, Cecil Fernandez]
# 40                                                        [Potacho Garcia Moreno, Ivan Peña]
# 41                                                 [Martin Molestina Luzuriaga, delgadito92]
# 42                                                    [Cecil Fernandez, Garcia.cobo.alberto]
# 43                                                   [Martin Molestina Luzuriaga, Ivan Peña]
# 44                                                    [Cecil Fernandez, Garcia.cobo.alberto]
# 45                                                                  [Sonia Fresa, Ivan Peña]
# 46                                       [Martin Molestina Luzuriaga, Potacho Garcia Moreno]
# 47                               [Sonia Fresa, Potacho Garcia Moreno, Potacho Garcia Moreno]
# 48                                                   [Martin Molestina Luzuriaga, Ivan Peña]
# 49                                    [Martin Molestina Luzuriaga, delgadito92, delgadito92]
# ..                                                                                       ...
# 76                                               [Martin Molestina Luzuriaga, Juanjo P Fdez]
# 77           [Martin Molestina Luzuriaga, Martin Molestina Luzuriaga, Potacho Garcia Moreno]
# 78                                                                   [Juanjo P Fdez, merloc]
# 79                                                            [Sonia Fresa, Cecil Fernandez]
# 80                                             [Martin Molestina Luzuriaga, Cecil Fernandez]
# 81                                          [Martin Molestina Luzuriaga, Domènec Melé Casas]
# 82                                                           [Ivan Peña, Domènec Melé Casas]
# 83                                                         [delgadito92, Domènec Melé Casas]
# 84                                                            [Sonia Fresa, Cecil Fernandez]
# 85                                                           [sithjacob, Domènec Melé Casas]
# 86                                       [Martin Molestina Luzuriaga, Potacho Garcia Moreno]
# 87                                                              [Cecil Fernandez, kaarlikds]
# 88                                                                  [sithjacob, delgadito92]
# 89                                               [Potacho Garcia Moreno, Domènec Melé Casas]
# 90                                                    [Cecil Fernandez, Garcia.cobo.alberto]
# 91                                                    [Cecil Fernandez, Garcia.cobo.alberto]
# 92                                                 [Martin Molestina Luzuriaga, delgadito92]
# 93                                               [Martin Molestina Luzuriaga, Juanjo P Fdez]
# 94                                       [Martin Molestina Luzuriaga, Potacho Garcia Moreno]
# 95                                    [Martin Molestina Luzuriaga, Sonia Fresa, Sonia Fresa]
# 96                                                     [Cecil Fernandez, Domènec Melé Casas]
# 97                                                 [Martin Molestina Luzuriaga, Sonia Fresa]
# 98                                                    [Cecil Fernandez, Garcia.cobo.alberto]
# 99                                                         [delgadito92, Domènec Melé Casas]
# 100                               [Martin Molestina Luzuriaga, Juanjo P Fdez, Juanjo P Fdez]
# 101                                                        [delgadito92, Domènec Melé Casas]
# 102                                            [Martin Molestina Luzuriaga, Cecil Fernandez]
# 103                                                   [Potacho Garcia Moreno, Juanjo P Fdez]
# 104                                                  [Marc Pomar Torres, Domènec Melé Casas]
# 105                                                                 [Sonia Fresa, Ivan Peña]
# 106                                 [Martin Molestina Luzuriaga, Sonia Fresa, Juanjo P Fdez]
# 107                                        [Martin Molestina Luzuriaga, Garcia.cobo.alberto]
# 108                                                [Garcia.cobo.alberto, Domènec Melé Casas]
# 109                                                             [Cecil Fernandez, Ivan Peña]
# 110                                                                 [sithjacob, delgadito92]
# 111                                                                [Cecil Fernandez, merloc]
# 112                           [Martin Molestina Luzuriaga, Cecil Fernandez, Cecil Fernandez]
# 113                                      [Martin Molestina Luzuriaga, Potacho Garcia Moreno]
# 114                                                [Martin Molestina Luzuriaga, delgadito92]
# 115                                                        [delgadito92, Domènec Melé Casas]
# 116                                                          [sithjacob, Domènec Melé Casas]
# 117          [Martin Molestina Luzuriaga, Martin Molestina Luzuriaga, Potacho Garcia Moreno]
# 118                                                [Martin Molestina Luzuriaga, Sonia Fresa]
# 119                                                                 [Sonia Fresa, Ivan Peña]
# 120                                                [Garcia.cobo.alberto, Domènec Melé Casas]
# 121                                            [Martin Molestina Luzuriaga, Cecil Fernandez]
# 122                                                [Martin Molestina Luzuriaga, Sonia Fresa]
# 123                                              [Martin Molestina Luzuriaga, Juanjo P Fdez]
# 124                                                  [Martin Molestina Luzuriaga, Ivan Peña]
# 125                                                                 [delgadito92, Ivan Peña]
#
# [126 rows x 5 columns]
#           ·················································
#           ·················································
#           ·················································
#
#           Here's your new combined playlist:
#
#           https://open.spotify.com/playlist/3pfIVuDJIIWEAT2o844byF
#
#           ENJOY!
#
# Elapsed time: 43.38039994239807

# %%
with open('artists_genres.json', 'w') as outfile:
    json.dump(artists_genres, outfile)

# %%
len(artists_genres)
# Out:
# 7803

# %%
![geo-myoffice.png](attachment:geo-myoffice.png)
